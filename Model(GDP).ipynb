# %%
import numpy as np
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
def change_type(data):
    for column in data.columns:
        if column != 'Year':
            data[f'{column}'] = data[f'{column}'].astype('float')
    return data

# %%
file_name = 'set_with_gdp'
df = pd.read_csv(f'Data/Train/{file_name}.csv')
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df_test = pd.read_csv(f'Data/Test/{file_name}.csv')
df_test.set_index([pd.Index(np.array(df_test['Unnamed: 0.1']))],inplace= True)
df_test.drop(columns = ['Unnamed: 0','Unnamed: 0.1'], inplace = True)

# %%
df.drop(columns = ['Notes','ISO3 Alpha-code','ISO2 Alpha-code', 'SDMX code**'], inplace = True)

# %%
df.columns[39]
# Out:
# 'Female Life Expectancy at Age 80 (years)'

# %%
df.drop(columns = df.columns[31:40], inplace = True)

# %%
for code in df['Parent code'].unique():
    print(df[df['Location code'] == code])
# Out:
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]
# Empty DataFrame
# Columns: [Region, subregion, country or area *, GDP, Year, Location code, Parent code, Total Population, as of 1 January (thousands), Total Population, as of 1 July (thousands), Male Population, as of 1 July (thousands), Female Population, as of 1 July (thousands), Population Density, as of 1 July (persons per square km), Population Sex Ratio, as of 1 July (males per 100 females), Median Age, as of 1 July (years), Natural Change, Births minus Deaths (thousands), Rate of Natural Change (per 1,000 population), Population Change (thousands), Population Growth Rate (percentage), Population Annual Doubling Time (years), Births (thousands), Births by women aged 15 to 19 (thousands), Crude Birth Rate (births per 1,000 population), Total Fertility Rate (live births per woman), Net Reproduction Rate (surviving daughters per woman), Mean Age Childbearing (years), Sex Ratio at Birth (males per 100 female births), Total Deaths (thousands), Male Deaths (thousands), Female Deaths (thousands), Crude Death Rate (deaths per 1,000 population), Life Expectancy at Birth, both sexes (years), Male Life Expectancy at Birth (years), Female Life Expectancy at Birth (years), Infant Deaths, under age 1 (thousands), Infant Mortality Rate (infant deaths per 1,000 live births), Live Births Surviving to Age 1 (thousands), Under-Five Deaths, under age 5 (thousands), Under-Five Mortality (deaths under age 5 per 1,000 live births), Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births), Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births), Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births), Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births), Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births), Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births), Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15), Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15), Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15), Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15), Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15), Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15), Net Number of Migrants (thousands), Net Migration Rate (per 1,000 population)]
# Index: []
#
# [0 rows x 50 columns]

# %%
is_drop = []
for code in df['Location code'].unique():
    temp = df[df['Location code'] == code]
    if len(temp['Region, subregion, country or area *'].unique()) != 1:
        is_drop.appned(0)
if len(is_drop) == 0:
    df.drop(columns = ['Region, subregion, country or area *'], inplace = True)

# %%
df = df.replace(to_replace='...', value= np.nan)

# %%
df = change_type(df)
df
# Out:
#          GDP    Year  Location code  Parent code  \
# 0        NaN  1980.0            4.0       5501.0
# 1      728.0  1980.0            8.0        925.0
# 2     2269.0  1980.0           12.0        912.0
# 3        NaN  1980.0           20.0        925.0
# 4      745.0  1980.0           24.0        911.0
# ...      ...     ...            ...          ...
# 7219  2002.0  2021.0          860.0       5500.0
# 7220  2970.0  2021.0          548.0        928.0
# 7221   644.0  2021.0          887.0        922.0
# 7222  1095.0  2021.0          894.0        910.0
# 7223  2122.0  2021.0          716.0        910.0
#
#       Total Population, as of 1 January (thousands)  \
# 0                                         12917.355
# 1                                          2915.703
# 2                                         18442.659
# 3                                            34.908
# 4                                          8182.314
# ...                                             ...
# 7219                                      33809.850
# 7220                                        315.398
# 7221                                      32640.962
# 7222                                      19200.512
# 7223                                      15834.106
#
#       Total Population, as of 1 July (thousands)  \
# 0                                      12486.631
# 1                                       2941.651
# 2                                      18739.378
# 3                                         35.611
# 4                                       8330.047
# ...                                          ...
# 7219                                   34081.449
# 7220                                     319.137
# 7221                                   32981.641
# 7222                                   19473.125
# 7223                                   15993.524
#
#       Male Population, as of 1 July (thousands)  \
# 0                                      6349.775
# 1                                      1525.259
# 2                                      9552.367
# 3                                        19.052
# 4                                      4165.901
# ...                                         ...
# 7219                                  17051.893
# 7220                                    160.506
# 7221                                  16668.432
# 7222                                   9609.004
# 7223                                   7543.690
#
#       Female Population, as of 1 July (thousands)  \
# 0                                        6136.856
# 1                                        1416.392
# 2                                        9187.012
# 3                                          16.559
# 4                                        4164.145
# ...                                           ...
# 7219                                    17029.555
# 7220                                      158.631
# 7221                                    16313.210
# 7222                                     9864.121
# 7223                                     8449.834
#
#       Population Density, as of 1 July (persons per square km)  \
# 0                                                19.231
# 1                                               107.367
# 2                                                 7.868
# 3                                                75.768
# 4                                                 6.682
# ...                                                 ...
# 7219                                             80.116
# 7220                                             26.180
# 7221                                             62.469
# 7222                                             26.195
# 7223                                             41.343
#
#       Population Sex Ratio, as of 1 July (males per 100 females)  ...  \
# 0                                               103.470           ...
# 1                                               107.686           ...
# 2                                               103.977           ...
# 3                                               115.049           ...
# 4                                               100.042           ...
# ...                                                 ...           ...
# 7219                                            100.131           ...
# 7220                                            101.182           ...
# 7221                                            102.178           ...
# 7222                                             97.414           ...
# 7223                                             89.276           ...
#
#       Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)  \
# 0                                               704.375
# 1                                               206.554
# 2                                               472.467
# 3                                               123.148
# 4                                               665.234
# ...                                                 ...
# 7219                                            217.644
# 7220                                            212.685
# 7221                                            347.585
# 7222                                            414.859
# 7223                                            492.685
#
#       Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births)  \
# 0                                               617.683
# 1                                               140.002
# 2                                               418.768
# 3                                                68.832
# 4                                               550.234
# ...                                                 ...
# 7219                                            131.727
# 7220                                            152.330
# 7221                                            225.259
# 7222                                            297.382
# 7223                                            365.858
#
#       Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15)  \
# 0                                               367.132
# 1                                                56.395
# 2                                               191.216
# 3                                                33.047
# 4                                               323.183
# ...                                                 ...
# 7219                                             65.331
# 7220                                             71.966
# 7221                                            124.294
# 7222                                            168.411
# 7223                                            226.668
#
#       Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15)  \
# 0                                               414.173
# 1                                                68.925
# 2                                               204.628
# 3                                                40.078
# 4                                               382.693
# ...                                                 ...
# 7219                                             82.439
# 7220                                             83.294
# 7221                                            164.127
# 7222                                            202.990
# 7223                                            272.194
#
#       Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15)  \
# 0                                               313.674
# 1                                                42.123
# 2                                               177.606
# 3                                                24.698
# 4                                               259.871
# ...                                                 ...
# 7219                                             48.100
# 7220                                             60.447
# 7221                                             81.618
# 7222                                            133.336
# 7223                                            188.179
#
#       Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)  \
# 0                                               521.206
# 1                                               113.200
# 2                                               326.761
# 3                                                82.599
# 4                                               454.537
# ...                                                 ...
# 7219                                            162.158
# 7220                                            157.780
# 7221                                            235.095
# 7222                                            309.112
# 7223                                            386.447
#
#       Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15)  \
# 0                                               575.356
# 1                                               138.768
# 2                                               357.691
# 3                                               106.366
# 4                                               521.651
# ...                                                 ...
# 7219                                            204.122
# 7220                                            187.403
# 7221                                            294.032
# 7222                                            368.647
# 7223                                            456.323
#
#       Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15)  \
# 0                                               456.101
# 1                                                86.186
# 2                                               295.197
# 3                                                56.321
# 4                                               380.987
# ...                                                 ...
# 7219                                            120.386
# 7220                                            129.156
# 7221                                            171.918
# 7222                                            250.213
# 7223                                            326.282
#
#       Net Number of Migrants (thousands)  \
# 0                              -1205.401
# 1                                 -9.135
# 2                                 29.298
# 3                                  0.959
# 4                                 53.078
# ...                                  ...
# 7219                             -39.201
# 7220                              -0.197
# 7221                            -101.468
# 7222                               9.015
# 7223                             -25.005
#
#       Net Migration Rate (per 1,000 population)
# 0                                       -92.075
# 1                                        -3.101
# 2                                         1.564
# 3                                        27.250
# 4                                         6.390
# ...                                         ...
# 7219                                     -1.150
# 7220                                     -0.617
# 7221                                     -3.072
# 7222                                      0.463
# 7223                                     -1.562
#
# [7224 rows x 49 columns]

# %%
df[df['Year'] == 2021]
# Out:
#           GDP    Year  Location code  Parent code  \
# 7052    611.0  2021.0            4.0       5501.0
# 7053   6373.0  2021.0            8.0        925.0
# 7054   3660.0  2021.0           12.0        912.0
# 7055  41873.0  2021.0           20.0        925.0
# 7056   2352.0  2021.0           24.0        911.0
# ...       ...     ...            ...          ...
# 7219   2002.0  2021.0          860.0       5500.0
# 7220   2970.0  2021.0          548.0        928.0
# 7221    644.0  2021.0          887.0        922.0
# 7222   1095.0  2021.0          894.0        910.0
# 7223   2122.0  2021.0          716.0        910.0
#
#       Total Population, as of 1 January (thousands)  \
# 7052                                      39618.434
# 7053                                       2861.567
# 7054                                      43812.345
# 7055                                         78.380
# 7056                                      33957.975
# ...                                             ...
# 7219                                      33809.850
# 7220                                        315.398
# 7221                                      32640.962
# 7222                                      19200.512
# 7223                                      15834.106
#
#       Total Population, as of 1 July (thousands)  \
# 7052                                   40099.462
# 7053                                    2854.710
# 7054                                   44177.969
# 7055                                      79.034
# 7056                                   34503.774
# ...                                          ...
# 7219                                   34081.449
# 7220                                     319.137
# 7221                                   32981.641
# 7222                                   19473.125
# 7223                                   15993.524
#
#       Male Population, as of 1 July (thousands)  \
# 7052                                  20254.878
# 7053                                   1425.955
# 7054                                  22497.244
# 7055                                     40.361
# 7056                                  17051.491
# ...                                         ...
# 7219                                  17051.893
# 7220                                    160.506
# 7221                                  16668.432
# 7222                                   9609.004
# 7223                                   7543.690
#
#       Female Population, as of 1 July (thousands)  \
# 7052                                    19844.584
# 7053                                     1428.755
# 7054                                    21680.725
# 7055                                       38.673
# 7056                                    17452.283
# ...                                           ...
# 7219                                    17029.555
# 7220                                      158.631
# 7221                                    16313.210
# 7222                                     9864.121
# 7223                                     8449.834
#
#       Population Density, as of 1 July (persons per square km)  \
# 7052                                             61.758
# 7053                                            104.194
# 7054                                             18.549
# 7055                                            168.157
# 7056                                             27.676
# ...                                                 ...
# 7219                                             80.116
# 7220                                             26.180
# 7221                                             62.469
# 7222                                             26.195
# 7223                                             41.343
#
#       Population Sex Ratio, as of 1 July (males per 100 females)  ...  \
# 7052                                            102.068           ...
# 7053                                             99.804           ...
# 7054                                            103.766           ...
# 7055                                            104.362           ...
# 7056                                             97.704           ...
# ...                                                 ...           ...
# 7219                                            100.131           ...
# 7220                                            101.182           ...
# 7221                                            102.178           ...
# 7222                                             97.414           ...
# 7223                                             89.276           ...
#
#       Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)  \
# 7052                                            389.515
# 7053                                            133.208
# 7054                                            119.901
# 7055                                             97.817
# 7056                                            390.508
# ...                                                 ...
# 7219                                            217.644
# 7220                                            212.685
# 7221                                            347.585
# 7222                                            414.859
# 7223                                            492.685
#
#       Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births)  \
# 7052                                            264.377
# 7053                                             72.920
# 7054                                             86.254
# 7055                                             47.523
# 7056                                            284.773
# ...                                                 ...
# 7219                                            131.727
# 7220                                            152.330
# 7221                                            225.259
# 7222                                            297.382
# 7223                                            365.858
#
#       Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15)  \
# 7052                                            159.895
# 7053                                             40.728
# 7054                                             35.549
# 7055                                             21.252
# 7056                                            152.331
# ...                                                 ...
# 7219                                             65.331
# 7220                                             71.966
# 7221                                            124.294
# 7222                                            168.411
# 7223                                            226.668
#
#       Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15)  \
# 7052                                            206.673
# 7053                                             52.789
# 7054                                             41.474
# 7055                                             27.171
# 7056                                            183.474
# ...                                                 ...
# 7219                                             82.439
# 7220                                             83.294
# 7221                                            164.127
# 7222                                            202.990
# 7223                                            272.194
#
#       Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15)  \
# 7052                                            109.411
# 7053                                             28.579
# 7054                                             29.294
# 7055                                             15.133
# 7056                                            121.715
# ...                                                 ...
# 7219                                             48.100
# 7220                                             60.447
# 7221                                             81.618
# 7222                                            133.336
# 7223                                            188.179
#
#       Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)  \
# 7052                                            280.261
# 7053                                             92.100
# 7054                                             80.338
# 7055                                             66.483
# 7056                                            278.765
# ...                                                 ...
# 7219                                            162.158
# 7220                                            157.780
# 7221                                            235.095
# 7222                                            309.112
# 7223                                            386.447
#
#       Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15)  \
# 7052                                            342.158
# 7053                                            122.111
# 7054                                             95.798
# 7055                                             90.535
# 7056                                            331.364
# ...                                                 ...
# 7219                                            204.122
# 7220                                            187.403
# 7221                                            294.032
# 7222                                            368.647
# 7223                                            456.323
#
#       Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15)  \
# 7052                                            214.241
# 7053                                             62.136
# 7054                                             63.984
# 7055                                             40.426
# 7056                                            227.092
# ...                                                 ...
# 7219                                            120.386
# 7220                                            129.156
# 7221                                            171.918
# 7222                                            250.213
# 7223                                            326.282
#
#       Net Number of Migrants (thousands)  \
# 7052                            -183.672
# 7053                             -10.612
# 7054                             -18.797
# 7055                               1.377
# 7056                              29.089
# ...                                  ...
# 7219                             -39.201
# 7220                              -0.197
# 7221                            -101.468
# 7222                               9.015
# 7223                             -25.005
#
#       Net Migration Rate (per 1,000 population)
# 7052                                     -4.569
# 7053                                     -3.710
# 7054                                     -0.425
# 7055                                     17.556
# 7056                                      0.843
# ...                                         ...
# 7219                                     -1.150
# 7220                                     -0.617
# 7221                                     -3.072
# 7222                                      0.463
# 7223                                     -1.562
#
# [172 rows x 49 columns]

# %%
y_start = 27
y_end = 30
df[df.columns[27:30]]
# Out:
#       Life Expectancy at Birth, both sexes (years)  \
# 0                                           39.618
# 1                                           70.478
# 2                                           53.261
# 3                                           76.840
# 4                                           42.449
# ...                                            ...
# 7219                                        70.862
# 7220                                        70.449
# 7221                                        63.753
# 7222                                        61.223
# 7223                                        59.253
#
#       Male Life Expectancy at Birth (years)  \
# 0                                    37.799
# 1                                    68.048
# 2                                    51.983
# 3                                    74.075
# 4                                    39.630
# ...                                     ...
# 7219                                 68.334
# 7220                                 68.397
# 7221                                 60.629
# 7222                                 58.487
# 7223                                 56.232
#
#       Female Life Expectancy at Birth (years)
# 0                                      41.720
# 1                                      72.986
# 2                                      54.629
# 3                                      80.367
# 4                                      45.608
# ...                                       ...
# 7219                                   73.390
# 7220                                   72.945
# 7221                                   67.134
# 7222                                   63.928
# 7223                                   62.045
#
# [7224 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
heat_map = df.corr()[y_start:y_end].transpose()
# targets = np.array([26,27,28])
# res = [ele for idx, ele in enumerate(np.arange(len(heat_map.columns))) if idx not in targets]
# heat_map = df[df.columns].corr().iloc[targets]
# heat_map = heat_map[heat_map.columns[res]].transpose()

# %%
plt.figure(figsize=(20,20))
dataplot = sns.heatmap(heat_map, cmap= sns.color_palette("vlag"), annot=True)
plt.show()

# %%
threshold = 0.5
features = heat_map[(heat_map['Life Expectancy at Birth, both sexes (years)'] >= threshold) 
                   | (heat_map['Life Expectancy at Birth, both sexes (years)'] <= - threshold)]
features.drop(['Male Life Expectancy at Birth (years)',
                        'Female Life Expectancy at Birth (years)',
                          'Life Expectancy at Birth, both sexes (years)'], inplace = True)

# %%
features = features.index
len(features)
# Out:
# 13

# %%
heat_map_x = df[features].corr()
plt.figure(figsize=(20,20))
dataplot = sns.heatmap(heat_map_x, cmap= sns.color_palette("vlag"), annot=True)
plt.show()

# %%
features = features.drop([
#        'Male Mortality before Age 40 (deaths under age 40 per 1,000 male live births)',
#        'Female Mortality before Age 40 (deaths under age 40 per 1,000 female live births)',
# #        'Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births)',
#        'Male Mortality before Age 60 (deaths under age 60 per 1,000 male live births)',
#        'Female Mortality before Age 60 (deaths under age 60 per 1,000 female live births)',
# #        'Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15)',
#        'Male Mortality between Age 15 and 50 (deaths under age 50 per 1,000 males alive at age 15)',
#        'Female Mortality between Age 15 and 50 (deaths under age 50 per 1,000 females alive at age 15)',
# #        'Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)',
#        'Male Mortality between Age 15 and 60 (deaths under age 60 per 1,000 males alive at age 15)',
#        'Female Mortality between Age 15 and 60 (deaths under age 60 per 1,000 females alive at age 15)'
    
])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
# X_train, X_test, y_train, y_test = train_test_split(df[features.drop('Year')],df[df.columns[26:29]])
df.dropna(inplace = True)
X_train, X_test, y_train, y_test = train_test_split(df[features],df[df.columns[y_start:y_end]])
reg = KNeighborsRegressor(n_neighbors=2 ,p = 1)
reg.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2, p=1)

# %%
y_hat = reg.predict(X_test)
for i in range (3):
    print(f'R2 for Evaluation {y_test.columns[i]}: {r2_score(y_test[y_test.columns[i]],y_hat[ :,i])}')
# Out:
# R2 for Evaluation Life Expectancy at Birth, both sexes (years): 0.9820483825766825
# R2 for Evaluation Male Life Expectancy at Birth (years): 0.9795222650171026
# R2 for Evaluation Female Life Expectancy at Birth (years): 0.9728820037346455

# %%
# X_2022 = df_test[features.drop('Year')]
X_2022 = df_test[features]
y_2022 = df_test[y_test.columns]

# %%
for i in X_2022.columns:
    print(i)
    print(X_2022[X_2022[i] == '...'].index)
for i in y_2022.columns:
    print(i)
    print(y_2022[y_2022[i] == '...'].index)
# Out:
# GDP
# Int64Index([], dtype='int64')
# Median Age, as of 1 July (years)
# Int64Index([], dtype='int64')
# Rate of Natural Change (per 1,000 population)
# Int64Index([], dtype='int64')
# Crude Birth Rate (births per 1,000 population)
# Int64Index([], dtype='int64')
# Total Fertility Rate (live births per woman)
# Int64Index([], dtype='int64')
# Net Reproduction Rate (surviving daughters per woman)
# Int64Index([], dtype='int64')
# Crude Death Rate (deaths per 1,000 population)
# Int64Index([], dtype='int64')
# Infant Mortality Rate (infant deaths per 1,000 live births)
# Int64Index([], dtype='int64')
# Under-Five Mortality (deaths under age 5 per 1,000 live births)
# Int64Index([], dtype='int64')
# Mortality before Age 40, both sexes (deaths under age 40 per 1,000 live births)
# Int64Index([], dtype='int64')
# Mortality before Age 60, both sexes (deaths under age 60 per 1,000 live births)
# Int64Index([], dtype='int64')
# Mortality between Age 15 and 50, both sexes (deaths under age 50 per 1,000 alive at age 15)
# Int64Index([], dtype='int64')
# Mortality between Age 15 and 60, both sexes (deaths under age 60 per 1,000 alive at age 15)
# Int64Index([], dtype='int64')
# Life Expectancy at Birth, both sexes (years)
# Int64Index([], dtype='int64')
# Male Life Expectancy at Birth (years)
# Int64Index([], dtype='int64')
# Female Life Expectancy at Birth (years)
# Int64Index([], dtype='int64')

# %%
# X_2022.drop(X_2022.loc[10981],inplace = True)
# y_2022.drop(['10981'],inplace = True)
# df_test.drop(['10981'],inplace = True)

# %%
y_2022
# Out:
#        Life Expectancy at Birth, both sexes (years)  \
# 8141                                         62.879
# 13513                                        76.833
# 4349                                         77.129
# 13592                                        83.552
# 3559                                         61.929
# ...                                             ...
# 7272                                         71.674
# 21097                                        70.492
# 11222                                        63.720
# 3322                                         61.803
# 3401                                         59.391
#
#        Male Life Expectancy at Birth (years)  \
# 8141                                  59.766
# 13513                                 74.502
# 4349                                  75.853
# 13592                                 81.430
# 3559                                  59.351
# ...                                      ...
# 7272                                  69.032
# 21097                                 68.316
# 11222                                 60.493
# 3322                                  59.058
# 3401                                  56.428
#
#        Female Life Expectancy at Birth (years)
# 8141                                    66.213
# 13513                                   79.472
# 4349                                    78.457
# 13592                                   85.838
# 3559                                    64.541
# ...                                        ...
# 7272                                    74.293
# 21097                                   73.067
# 11222                                   67.222
# 3322                                    64.510
# 3401                                    62.094
#
# [172 rows x 3 columns]

# %%
df_test['Location code']
# Out:
# 8141       4
# 13513      8
# 4349      12
# 13592     20
# 3559      24
#         ...
# 7272     860
# 21097    548
# 11222    887
# 3322     894
# 3401     716
# Name: Location code, Length: 172, dtype: int64

# %%
y_hat = reg.predict(X_2022)
for i in range (3):
    y = np.array(y_2022[y_2022.columns[i]].astype('float'))
    plt.figure(figsize=(15,5))
    plt.plot(np.transpose(y_hat)[i])
    plt.plot(y)
    plt.title(f'R2 for 2022 {y_2022.columns[i]}: {r2_score(y,y_hat[ :,i])}')
    plt.legend(['predict', 'test'], loc='lower right')
    plt.show()

# %%
y_hat[df_test['Region, subregion, country or area *'] == 'Zimbabwe']
# Out:
# array([[60.024, 57.501, 62.351]])

# %%
y_2022[df_test['Region, subregion, country or area *'] == 'Zimbabwe']
# Out:
#       Life Expectancy at Birth, both sexes (years)  \
# 3401                                        59.391
#
#       Male Life Expectancy at Birth (years)  \
# 3401                                 56.428
#
#       Female Life Expectancy at Birth (years)
# 3401                                   62.094

# %%
save_path = './Result/Baseline(GPD)'
file_name = 'y_hat'
np.save(f'{save_path}/{file_name}',y_hat)
file_name = 'y_2022'
y_2022.to_csv(f'{save_path}/{file_name}.csv')
file_name = 'X_2022'
X_2022.to_csv(f'{save_path}/{file_name}.csv')
